# %% [markdown]
# - In-built function
# - User defined function
# - Anonymous Function

# %% [markdown]
# Function definetion

# %%
def addNumber():#function name
    a = 45      #function body
    b = 34
    print(a+b)

# %%
addNumber() #function call
# Out:
# 79

# %%
def addition():
    num1 = int(input("Enter the number: "))
    num2 = int(input("Enter the number: "))

    print("Result is of ",num1,"&",num2 ,"is : ",num1+num2)

# %%
addition()
# Out:
# Result is of  32 & 45 is :  77

# %%
def subtract(num1,num2):
    print(num1-num2)

# %%
subtract(12,34)
# Out:
# -22

# %%
def greet(name="Guest"):
    print("Hello, ",name)

# %%
greet("Krish")
# Out:
# Hello,  Krish

# %%
def factorial(num):
    fact = 1
    for i in range(num):
        fact = fact * (i+1)
        # print("i: ",i, "n: ",i+1, "Factorial: ",fact)

    return fact

# %%
factorial(5)
# Out:
# 120

# %% [markdown]
# Anonymous function

# %%
x = lambda n:n**2

# %%
x(89)
# Out:
# 7921

# %%
res = lambda x1,x2,x3:x1+x2+x3

# %%
res(34,23,67)
# Out:
# 124
