# %% [markdown]
# Datastructure , where we store the data so we could reuse it.

# %% [markdown]
# List, tuple, set , dictionary

# %% [markdown]
# <h2>List</h2>

# %%
arr = [1,2,3,4,5,5,4,6,4]

# %%
type(arr)
# Out:
# list

# %%
num = 34

# %%
names = ["rohan","sohit","karan","abhishek"]

# %%
type(names)
# Out:
# list

# %%
data = [34,"text",34.32,True]

# %%
type(data)
# Out:
# list

# %%
arr = [34,56,49,36,48]

# %%
arr.append(34)

# %%
arr
# Out:
# [34, 56, 49, 36, 48, 34, 34]

# %%
arr.append("hello")

# %%
arr
# Out:
# [34, 56, 49, 36, 48, 34, 34, 'hello']

# %%
arr.insert(3,57)

# %%
arr
# Out:
# [34, 56, 49, 57, 36, 48, 34, 34, 'hello']

# %%
arr.pop()
# Out:
# 34

# %%
arr
# Out:
# [34, 56, 49, 57, 36, 48, 34]

# %%
arr.remove(57)

# %%
arr
# Out:
# [34, 56, 49, 36, 48, 34]

# %%
arr.remove(37)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 arr.remove(37)
#
# ValueError: list.remove(x): x not in list

# %%
arr.remove(34)

# %%
arr
# Out:
# [56, 49, 36, 48, 34]

# %%
arr.pop(3)
# Out:
# 48

# %%
arr
# Out:
# [56, 49, 36, 34, 36, 36]

# %%
arr.append(36)

# %%
arr.count(36)
# Out:
# 3

# %%
arr.reverse()

# %%
arr
# Out:
# [36, 36, 34, 36, 49, 56]

# %%
arr.clear()

# %%
arr
# Out:
# []

# %% [markdown]
# <h2>Tuple</h2>

# %%
tp = (23,12,34,5,65,76)

# %%
type(tp)
# Out:
# tuple

# %%
tp.count(12)
# Out:
# 1

# %%
tp.index(34)
# Out:
# 2

# %%
tp.append(23)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 tp.append(23)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# <h2>Set</h2>

# %%
st1 = {1,2,3,4,3,5}
st2 = {3,2,3,5,6,7}

# %%
st1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
st2
# Out:
# {2, 3, 5, 6, 7, 8}

# %%
st1.add(3)

# %%
st1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
st2
# Out:
# {2, 3, 5, 6, 7, 8}

# %%
s1 = {2,3}

# %%
s1.issubset(st1)
# Out:
# True

# %%
st1.issuperset(s1)
# Out:
# True

# %%
st1.difference(st2)
# Out:
# {1, 4}

# %%
st2.difference(st1)
# Out:
# {7, 8}

# %%
st1.union(st2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
st1.intersection(st2)
# Out:
# {2, 3, 5, 6}

# %%
st1.remove(5)

# %%
st1
# Out:
# {1, 2, 3, 4, 6}

# %%
st1.remove(34)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 st1.remove(34)
#
# KeyError: 34

# %%
st1.discard(34)

# %%
st1.clear()

# %%
st1
# Out:
# set()

# %% [markdown]
# <h2>Dictionary</h2>

# %% [markdown]
# It's key value pair type datastructure

# %%
student = {
    "name":"Krish",
    "Age":24,
    45:"Value"
}

# %%
student[45]
# Out:
# 'Value'

# %%
students = {
    "Name":["Riddhi","Sohit","Rudra","Krish"],
    "Age":[34,23,12,34],
    "Course":["DS","BA","DA","AI"]

}

# %%
students
# Out:
# {'Name': ['Riddhi', 'Sohit', 'Rudra', 'Krish'],
#  'Age': [34, 23, 12, 34],
#  'Course': ['DS', 'BA', 'DA', 'AI']}

# %%
students.keys()
# Out:
# dict_keys(['Name', 'Age', 'Course'])

# %%
students.values()
# Out:
# dict_values([['Riddhi', 'Sohit', 'Rudra', 'Krish'], [34, 23, 12, 34], ['DS', 'BA', 'DA', 'AI']])

# %%
students.items()
# Out:
# dict_items([('Name', ['Riddhi', 'Sohit', 'Rudra', 'Krish']), ('Age', [34, 23, 12, 34]), ('Course', ['DS', 'BA', 'DA', 'AI'])])
