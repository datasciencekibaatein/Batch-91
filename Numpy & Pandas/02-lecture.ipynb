# %%
import numpy as np
import pandas as pd

# %% [markdown]
# CSV,Excel,JSON,API,TXT

# %%
students={
    "Name":['Rohan','Aman','Krish','Neha'],
    "Age":[23,22,34,12],
    'Marks':[45,55,45,43]
}

# %%
df = pd.DataFrame(students)

# %%
df.ndim
# Out:
# 2

# %%
age = [23,22,34,12]

pd.Series(age).ndim
# Out:
# 1

# %%
data = pd.read_csv("realworld_sales_dataset.csv")

# %%
len(data)
# Out:
# 2000

# %%
data.head()
# Out:
#    OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 0     1152  2024-07-27   2024-08-04  Customer_327  Electronics   West
# 1      500  2024-02-23   2024-03-04  Customer_426  Electronics  North
# 2     1337  2022-04-27   2022-05-06  Customer_379  Electronics   East
# 3     1033  2022-02-24   2022-03-02  Customer_381         Food   West
# 4      281  2023-11-16   2023-11-19  Customer_208    Furniture  South
#
#      Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# 0  Wholesale        15     271.72             True     3668.220
# 1     Online        17     433.52            False     7369.840
# 2     Retail         6     434.97            False     2609.820
# 3  Wholesale        12     283.51             True     3061.908
# 4     Retail        15      49.16             True      663.660

# %%
data.tail(5)
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 1995      894  2022-06-05   2022-06-08  Customer_247    Furniture  South
# 1996     1837  2024-03-30   2024-04-08  Customer_427         Food  North
# 1997     1702  2023-06-01   2023-06-07  Customer_135    Furniture   East
# 1998      957  2024-02-14   2024-02-19   Customer_64    Furniture   West
# 1999      939  2024-12-13   2024-12-22   Customer_25  Electronics  North
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# 1995  Wholesale         6     248.45            False     1490.700
# 1996  Wholesale        16     194.62             True     2802.528
# 1997     Online         6     118.02            False      708.120
# 1998     Online         6     487.15             True     2630.610
# 1999  Wholesale        14     136.99            False     1917.860

# %%
data['Category'].unique()
# Out:
# <ArrowStringArray>
# ['Electronics', 'Food', 'Furniture', 'Clothing']
# Length: 4, dtype: str

# %%
data.iloc[0:3,4:7]
# Out:
#       Category Region    Channel
# 0  Electronics   West  Wholesale
# 1  Electronics  North     Online
# 2  Electronics   East     Retail

# %%
data.loc[0:4,'OrderID':'Category'].transpose()
# Out:
#                          0             1             2             3  \
# OrderID               1152           500          1337          1033
# OrderDate       2024-07-27    2024-02-23    2022-04-27    2022-02-24
# ShipmentDate    2024-08-04    2024-03-04    2022-05-06    2022-03-02
# CustomerName  Customer_327  Customer_426  Customer_379  Customer_381
# Category       Electronics   Electronics   Electronics          Food
#
#                          4
# OrderID                281
# OrderDate       2023-11-16
# ShipmentDate    2023-11-19
# CustomerName  Customer_208
# Category         Furniture

# %%
data['CostAmount'] = data['Quantity']*data['UnitPrice']

# %%
data.head()
# Out:
#    OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 0     1152  2024-07-27   2024-08-04  Customer_327  Electronics   West
# 1      500  2024-02-23   2024-03-04  Customer_426  Electronics  North
# 2     1337  2022-04-27   2022-05-06  Customer_379  Electronics   East
# 3     1033  2022-02-24   2022-03-02  Customer_381         Food   West
# 4      281  2023-11-16   2023-11-19  Customer_208    Furniture  South
#
#      Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount  CostAmount
# 0  Wholesale        15     271.72             True     3668.220     4075.80
# 1     Online        17     433.52            False     7369.840     7369.84
# 2     Retail         6     434.97            False     2609.820     2609.82
# 3  Wholesale        12     283.51             True     3061.908     3402.12
# 4     Retail        15      49.16             True      663.660      737.40

# %%
data.sort_values(['Quantity','UnitPrice'],ascending=False)
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 1778      805  2022-06-06   2022-06-14  Customer_352  Electronics   West
# 1086      938  2022-11-24   2022-12-02  Customer_425    Furniture  North
# 685      1330  2023-03-31   2023-04-04  Customer_261    Furniture   East
# 1824     1027  2022-01-11   2022-01-17  Customer_270     Clothing   West
# 1069     1298  2024-11-11   2024-11-15  Customer_365    Furniture   East
# ...       ...         ...          ...           ...          ...    ...
# 1218      579  2024-09-16   2024-09-17  Customer_214         Food   West
# 493      1321  2022-12-15   2022-12-21  Customer_288     Clothing   East
# 1397      287  2024-08-29   2024-09-04   Customer_72     Clothing   West
# 1904     1405  2024-06-27   2024-07-01  Customer_435         Food  South
# 72        428  2024-04-30   2024-05-04  Customer_273     Clothing   East
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount  CostAmount
# ...

# %%
data.groupby(['Category','Region'])[['SalesAmount','Quantity']].sum()
# Out:
#                     SalesAmount  Quantity
# Category    Region
# Clothing    East     330373.499      1431
#             North    289477.314      1251
#             South    314403.655      1332
#             West     350246.180      1375
# Electronics East     360818.577      1442
#             North    301370.412      1216
#             South    316755.458      1278
#             West     338547.522      1363
# Food        East     250346.189      1124
#             North    296408.627      1237
#             South    302344.959      1364
#             West     271111.789      1094
# Furniture   East     262142.428      1081
#             North    328052.310      1243
#             South    356538.774      1466
#             West     248942.971      1094

# %%
data.groupby(['Region','Category'])[['SalesAmount','Quantity']].agg(['sum','mean','count'])
# Out:
#                    SalesAmount                    Quantity
#                            sum         mean count      sum       mean count
# Region Category
# East   Clothing     330373.499  2359.810707   140     1431  10.221429   140
#        Electronics  360818.577  2488.403979   145     1442   9.944828   145
#        Food         250346.189  2296.754028   109     1124  10.311927   109
#        Furniture    262142.428  2427.244704   108     1081  10.009259   108
# North  Clothing     289477.314  2412.310950   120     1251  10.425000   120
#        Electronics  301370.412  2666.994796   113     1216  10.761062   113
#        Food         296408.627  2371.269016   125     1237   9.896000   125
#        Furniture    328052.310  2645.583145   124     1243  10.024194   124
# South  Clothing     314403.655  2346.295933   134     1332   9.940299   134
#        Electronics  316755.458  2554.479500   124     1278  10.306452   124
# ...

# %%
brief = data.pivot_table(values=['SalesAmount','Quantity'],columns=['Region','Channel'],index='Category')

# %%
brief.to_excel("xyz.xlsx")

# %%
data.isnull().sum()
# Out:
# OrderID            0
# OrderDate          0
# ShipmentDate       0
# CustomerName       0
# Category           0
# Region             0
# Channel            0
# Quantity           0
# UnitPrice          0
# DiscountApplied    0
# SalesAmount        0
# CostAmount         0
# dtype: int64

# %%
students={
    "Name":['Rohan','Aman','Krish','Neha'],
    "Age":[23,np.nan,34,np.nan],
    'Marks':[None,55,45,None]
}

df = pd.DataFrame(students)

# %%
df
# Out:
#     Name   Age  Marks
# 0  Rohan  23.0    NaN
# 1   Aman   NaN   55.0
# 2  Krish  34.0   45.0
# 3   Neha   NaN    NaN

# %%
df.isnull().mean()*100
# Out:
# Name      0.0
# Age      50.0
# Marks    50.0
# dtype: float64

# %%
employees = pd.read_excel("hr_multi_sheet_dataset.xlsx",sheet_name='Employees')
departments =pd.read_excel("hr_multi_sheet_dataset.xlsx",sheet_name='Departments')
locations = pd.read_excel("hr_multi_sheet_dataset.xlsx",sheet_name='Locations')
jobs = pd.read_excel("hr_multi_sheet_dataset.xlsx",sheet_name='Jobs')
attendance = pd.read_excel("hr_multi_sheet_dataset.xlsx",sheet_name='Attendance')
attrition = pd.read_excel("hr_multi_sheet_dataset.xlsx",sheet_name='Attrition')

# %%
employees.head()
# Out:
#    EmployeeID EmpCode  DeptID  LocationID  JobID   HireDate  Age  Gender  \
# 0           1   E0001       6           1      1 2021-01-31   36    Male
# 1           2   E0002       4           1      1 2019-01-19   34    Male
# 2           3   E0003       6           4      4 2023-01-14   58  Female
# 3           4   E0004       3           3      3 2020-05-31   42    Male
# 4           5   E0005       5           3      1 2026-03-08   50    Male
#
#   EmploymentStatus  Salary  PerformanceRating  TrainingHours  AbsenteeismDays  \
# 0           Active  644704                  1              8                5
# 1           Active  742129                  1              8                8
# 2           Active  921776                  1              2                0
# 3           Active  368277                  1              5                1
# 4         On Leave  551005                  4              1                6
#
# ...

# %%
departments
# Out:
#    DeptID  Department  Budget_USD  Headcount_Target
# 0       1          HR      300000                25
# 1       2     Finance      500000                30
# 2       3          IT      900000                60
# 3       4       Sales      700000                55
# 4       5   Marketing      450000                28
# 5       6  Operations      650000                40

# %%
locations.head()
# Out:
#    LocationID     City      State Region
# 0           1    Noida         UP  North
# 1           2  Lucknow         UP  North
# 2           3    Delhi      Delhi  North
# 3           4   Jaipur  Rajasthan   West

# %%
departments[['DeptID','Department']]
# Out:
#    DeptID  Department
# 0       1          HR
# 1       2     Finance
# 2       3          IT
# 3       4       Sales
# 4       5   Marketing
# 5       6  Operations

# %%
df = employees.merge(departments[['DeptID','Department']],how='left',on='DeptID')

# %%
dept_mapping = {
    "HR":"Human Resources",
    "Finance":"Finance Team",
    "IT":"Information Technology",
    "Sales":"Sales Team",
    "Marketing":"Marketing Team",
    "Operations":"Operation Team"
}

# %%
df['Department'] = df["Department"].map(dept_mapping)

# %%
df.head(10)
# Out:
#    EmployeeID EmpCode  DeptID  LocationID  JobID   HireDate  Age  Gender  \
# 0           1   E0001       6           1      1 2021-01-31   36    Male
# 1           2   E0002       4           1      1 2019-01-19   34    Male
# 2           3   E0003       6           4      4 2023-01-14   58  Female
# 3           4   E0004       3           3      3 2020-05-31   42    Male
# 4           5   E0005       5           3      1 2026-03-08   50    Male
# 5           6   E0006       6           3      4 2025-11-25   25    Male
# 6           7   E0007       1           4      5 2023-02-01   44    Male
# 7           8   E0008       6           1      3 2023-12-28   36    Male
# 8           9   E0009       3           1      4 2018-05-12   41  Female
# 9          10   E0010       4           4      8 2019-08-09   37    Male
#
#   EmploymentStatus  Salary  ...  TrainingHours  AbsenteeismDays  \
# 0           Active  644704  ...              8                5
# ...
